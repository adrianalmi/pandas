# %%
import pandas as pd

# %%
df = pd.read_csv('D:/00_Amdocs/06_Automatismo/doxplanning/Tools Postcheck/postcheck repositorio/3G.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   RC  RNC_Id  WBTS_Id  WCEL_Id     Site RNC_Name    WBTS_Name  \
# 0           0  rc7    1052     9637    19637  CL00033    RMON3  CL00033U100
# 1           1  rc7    1052     9637    29637  CL00033    RMON3  CL00033U100
# 2           2  rc7    1052     9637     9637  CL00033    RMON3  CL00033U100
# 3           3  rc7    1052     9557    19557  RO00019    RMON3  RO00019U100
# 4           4  rc7    1052     9557    29557  RO00019    RMON3  RO00019U100
#
#         WCEL_Name  MCC  ... WCelState  AdminCellState  SBTSId   version  \
# 0  CL00033U100MB1  748  ...         0               1   25014  RNCFP20C
# 1  CL00033U100MC1  748  ...         0               1   25014  RNCFP20C
# 2  CL00033U100MA1  748  ...         0               1   25014  RNCFP20C
# 3  RO00019U100MB1  748  ...         0               1   26026  RNCFP20C
# 4  RO00019U100MC1  748  ...         0               1   26026  RNCFP20C
#
#    MultiplePLMNListIncluded  PtxPrimaryCPICH  MaxDLPowerCapability  \
# ...

# %%
df[df['Site']=='BA00027'][['WCEL_Name','PtxPrimaryCPICH', 'MaxDLPowerCapability' , 'PtxCellMax']]
# Out:
#           WCEL_Name  PtxPrimaryCPICH  MaxDLPowerCapability  PtxCellMax
# 65   BA00027U100MB2              351                   460         460
# 66   BA00027U100MC2              351                   460         460
# 124  BA00027U100MA2              351                   460         460

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'RC', 'RNC_Id', 'WBTS_Id', 'WCEL_Id', 'Site', 'RNC_Name',
#        'WBTS_Name', 'WCEL_Name', 'MCC', 'MNC', 'LAC', 'SAC', 'UARFCN',
#        'PriScrCode', 'RAC', 'PtxCellMax', 'Tcell', 'WCelState',
#        'AdminCellState', 'SBTSId', 'version', 'MultiplePLMNListIncluded',
#        'PtxPrimaryCPICH', 'MaxDLPowerCapability', 'neswversion',
#        'wbtsswbuildid', 'rncswbuildid'],
#       dtype='object')
